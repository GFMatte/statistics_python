# %% [markdown]
# # Analysing 5000 TMDB Movies

# %%
import pandas as pd

# %%
tmdb5000 = pd.read_csv('tmdb_5000_movies.csv')
tmdb5000
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
tmdb5000.describe().round(1)
# Out:
#             budget        id  popularity       revenue  runtime  vote_average  \
# count       4803.0    4803.0      4803.0  4.803000e+03   4801.0        4803.0
# mean    29045039.9   57165.5        21.5  8.226064e+07    106.9           6.1
# std     40722391.3   88694.6        31.8  1.628571e+08     22.6           1.2
# min            0.0       5.0         0.0  0.000000e+00      0.0           0.0
# 25%       790000.0    9014.5         4.7  0.000000e+00     94.0           5.6
# 50%     15000000.0   14629.0        12.9  1.917000e+07    103.0           6.2
# 75%     40000000.0   58610.5        28.3  9.291719e+07    118.0           6.8
# max    380000000.0  459488.0       875.6  2.787965e+09    338.0          10.0
#
#        vote_count
# count      4803.0
# mean        690.2
# std        1234.6
# min           0.0
# 25%          54.0
# 50%         235.0
# 75%         737.0
# max       13752.0

# %% [markdown]
# ### Ploting with SNS

# %%
import seaborn as sns

# %%
sns.displot(tmdb5000.vote_average)

# %%
ax = sns.displot(tmdb5000.vote_average, stat= 'density', bins=50)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no TMDB 5000')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.distplot(tmdb5000.vote_average,norm_hist = False, kde= False)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no TMDB 5000')
ax.figure.set_size_inches(12,8)
# Out:
# D:\Users\guilh\anaconda3\envs\Matte_Alura_Pandas\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.displot(tmdb5000.vote_average, kde= False, bins= 50)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no TMDB 5000')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.boxplot(x= tmdb5000.vote_average)
ax.set_title('Distribuiçaõ de nota média dos filmes do TMBD 5000')
ax.set(xlabel= 'Nota média do filme')
ax.figure.set_size_inches(12,8)

# %% [markdown]
# ### Understanding the "0" average
# ***Movies with 0 average needs to be analyzed***

# %%
tmdb5000.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb5000_mais_de_10_votos = tmdb5000.query('vote_count >= 10')
tmdb5000_mais_de_10_votos.describe().round(2)
# Out:
#              budget         id  popularity       revenue  runtime  \
# count  4.392000e+03    4392.00     4392.00  4.392000e+03  4391.00
# mean   3.164545e+07   49204.12       23.45  8.990969e+07   108.43
# std    4.162736e+07   80136.25       32.59  1.682870e+08    21.01
# min    0.000000e+00       5.00        0.01  0.000000e+00     0.00
# 25%    2.895962e+06    8403.50        6.51  1.365700e+04    95.00
# 50%    1.700000e+07   13084.50       14.83  2.685837e+07   105.00
# 75%    4.200000e+07   46831.25       30.26  1.022818e+08   118.50
# max    3.800000e+08  417859.00      875.58  2.787965e+09   338.00
#
#        vote_average  vote_count
# count       4392.00     4392.00
# mean           6.23      754.44
# std            0.89     1272.26
# min            1.90       10.00
# 25%            5.70       83.75
# 50%            6.30      288.50
# 75%            6.80      831.00
# max            8.50    13752.00

# %%
ax = sns.displot(tmdb5000_mais_de_10_votos.vote_average, kde= False, bins= 50)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no TMDB 5000 dentre os filmes com 10 ou mais votos')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.displot(tmdb5000_mais_de_10_votos.vote_average, kde= True, bins= 50, stat= 'density')
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no TMDB 5000 dentre os filmes com 10 ou mais votos')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.boxplot(x= tmdb5000_mais_de_10_votos.vote_average)
ax.set_title('Distribuiçaõ de nota média dos filmes do TMBD 5000 dentre os filmes com 10 ou mais votos')
ax.set(xlabel= 'Nota média do filme')
ax.figure.set_size_inches(12,8)

# %% [markdown]
# # Analysing the Movielens database

# %%
notas = pd.read_csv('ratings.csv')

# %%
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.groupby('movieId').mean().rating
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
nota_media_por_filmes = notas.groupby('movieId').mean().rating
nota_media_por_filmes
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
ax = sns.displot(nota_media_por_filmes.values, kde= True, bins= 50)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no Movielens 100k')
ax.figure.set_size_inches(12,8)

# %%
quantidade_votos_filme = notas.groupby('movieId').count()
quantidade_votos_filme
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 4             7       7          7
# 5            49      49         49
# ...         ...     ...        ...
# 193581        1       1          1
# 193583        1       1          1
# 193585        1       1          1
# 193587        1       1          1
# 193609        1       1          1
#
# [9724 rows x 3 columns]

# %%
quantidade_votos_filme.query('rating >= 10')
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 2           110     110        110
# 3            52      52         52
# 5            49      49         49
# 6           102     102        102
# ...         ...     ...        ...
# 174055       13      13         13
# 176371       18      18         18
# 177765       13      13         13
# 179819       12      12         12
# 187593       12      12         12
#
# [2269 rows x 3 columns]

# %%
filmes_pelo_menos_10_votos = quantidade_votos_filme.query('rating >= 10').index
filmes_pelo_menos_10_votos
# Out:
# Int64Index([     1,      2,      3,      5,      6,      7,      9,     10,
#                 11,     12,
#             ...
#             166461, 166528, 166643, 168250, 168252, 174055, 176371, 177765,
#             179819, 187593],
#            dtype='int64', name='movieId', length=2269)

# %%
filmes_pelo_menos_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], dtype=int64)

# %%
nota_media_por_filmes
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %% [markdown]
# ### Finding just the movies with 10 or more votes inside de movielens db

# %%
nota_media_por_filmes.loc[filmes_pelo_menos_10_votos.values]
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
movielens_average_10_or_more_votes = nota_media_por_filmes.loc[filmes_pelo_menos_10_votos.values]

# %%
movielens_average_10_or_more_votes
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
ax = sns.displot(movielens_average_10_or_more_votes, kde= True, bins= 50)
ax.set(xlabel= 'Nota Média', title= 'Média de votos em filme no Movielens 100k com pelo menos 10 votos')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.boxplot(x= movielens_average_10_or_more_votes)
ax.set_title('Média de votos em filme no Movielens 100k')
ax.set(xlabel= 'Nota média do filme')
ax.figure.set_size_inches(12,8)

# %% [markdown]
# ### Plot empirical cumulative distribution functions (ecdf)

# %%
ax = sns.displot(movielens_average_10_or_more_votes, kind= 'ecdf')
ax.set(xlabel= 'Nota Média', ylabel= 'Porcentagem acumulada de filmes', title= 'Média de votos em filme no Movielens 100k com pelo menos 10 votos')
ax.figure.set_size_inches(12,8)

# %%
ax = sns.displot(tmdb5000_mais_de_10_votos.vote_average, kind= 'ecdf')
ax.set(xlabel= 'Nota Média', ylabel= 'Porcentagem acumulada de filmes', title= 'Média de votos do TMBD 5000 com pelo menos 10 votos')
ax.figure.set_size_inches(12,8)

# %% [markdown]
# ### Analyzing data of the movies

# %%
# Analysing the vote count
ax = sns.displot(tmdb5000_mais_de_10_votos.vote_count, bins= 50, kde= True, stat= 'density')
ax.set(xlabel = 'Número de votos', title = 'Número de votos em filmes do TMBD 5000 com pelo menos 10 votos')
ax.figure.set_size_inches(14, 10)

# %%
# Analysing the movies with budget > 0

# %%
tmdb5000.query('budget > 0').budget
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4791           13
# 4792        20000
# 4796         7000
# 4798       220000
# 4799         9000
# Name: budget, Length: 3766, dtype: int64

# %%
ax = sns.displot(tmdb5000.query('budget > 0').budget, bins= 50, kde= True, stat= 'density')
ax.set(xlabel = 'Budget', title = 'Gastos em filmes do TMDB 5000')
ax.figure.set_size_inches(14, 10)

# %%
# Analysing the series Popularity

# %%
tmdb5000.query('popularity == 0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %%
ax = sns.displot(tmdb5000.popularity, bins= 50, kde= True, stat= 'density')
ax.set(xlabel = 'Popularidade', title = 'Popularidade em filmes do TMDB 5000')
ax.figure.set_size_inches(14, 10)

# %%
# time duration
ax = sns.displot(tmdb5000.runtime, bins= 50, kde= True, stat= 'density')
ax.set(xlabel = 'Tempo de duração', title = 'Duração dos filmes do TMDB 5000')
ax.figure.set_size_inches(14, 10)

# %%
# Looking for Nulls
tmdb5000.runtime.isnull().sum()
# Out:
# 2

# %%
# Droping nulls
tmdb5000.runtime.dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
# time duration with dropped zeroes
ax = sns.displot(tmdb5000.query('runtime > 0').runtime.dropna(), bins= 50, kde= True, stat= 'density')
ax.set(xlabel = 'Tempo de duração', title = 'Duração dos filmes do TMDB 5000')
ax.figure.set_size_inches(14, 10)

# %%
ax = sns.displot(tmdb5000.query('runtime > 0').runtime.dropna(), kind= 'ecdf')
ax.set(xlabel= 'Duração', ylabel= '% de filmes', title= 'Tempo de duração em filmes no TMBD')
ax.figure.set_size_inches(12,8)

# %%
# getting the top 20% duration with pandas quantile
tmdb5000.query('runtime > 0').runtime.dropna().quantile(q=0.8)
# Out:
# 121.0

# %% [markdown]
# ## Movielens: movie average with at least 10 votes

# %%
# mean of movies with at leas 10 votes
movielens_average_10_or_more_votes.mean()
# Out:
# 3.4320503405352603

# %%
len(movielens_average_10_or_more_votes)
# Out:
# 2269

# %%
# for i in range (1, 2269):
movielens_average_10_or_more_votes[0:2269].mean()
# Out:
# 3.4320503405352603

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

np.random.seed(75243)
temp = movielens_average_10_or_more_votes.sample(frac=1) # Random sample of all items in movielens_.......

medias = []
for i in range(1, len(temp)):
    medias.append(temp[0:i].mean())
 
figure(figsize=(12, 8), dpi=80)
plt.plot(medias)

# %%
# doing the same as above with list comprehension

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

np.random.seed(75243)
temp = movielens_average_10_or_more_votes.sample(frac=1) # Random sample of all items in movielens_.......

medias = [temp[0:i].mean() for i in range(1, len(temp))]
 
figure(figsize=(12, 8), dpi=80)
plt.plot(medias)

# %%
# Using zconfint to determin the min max intervals (standard alplha 0.05)
from statsmodels.stats.weightstats import zconfint
zconfint(movielens_average_10_or_more_votes)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
# Comparting zconfint with tconfint_mean
from statsmodels.stats.weightstats import DescrStatsW

descr_average_10_or_more_votes = DescrStatsW(movielens_average_10_or_more_votes)
descr_average_10_or_more_votes.tconfint_mean()
# Out:
# (3.411234839229379, 3.4528658418411378)

# %% [markdown]
# # Analyzing movie 1

# %%
filmes = pd.read_csv('movies.csv')
filmes.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas_filme_1 = notas.query('movieId == 1')
notas_filme_1
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 516         5        1     4.0   847434962
# 874         7        1     4.5  1106635946
# 1434       15        1     2.5  1510577970
# 1667       17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [215 rows x 4 columns]

# %%
ax = sns.displot(notas_filme_1.rating, kde= True)
ax.set(xlabel = 'Notas', title = 'Notas do filme Toy Story')
ax.figure.set_size_inches(10, 8)

# %%
ax = sns.boxplot(x= notas_filme_1.rating)
ax.set_title('Notas do filme Tory Story')
ax.set(xlabel= 'Nota')
ax.figure.set_size_inches(12,8)

# %%
notas_filme_1.rating.mean()
# Out:
# 3.9209302325581397

# %%
# using ztest
low, high = zconfint(notas_filme_1.rating)
print(f'Lowest interval: {low.round(3)}, Highest interval: {high.round(3)}')
# Out:
# Lowest interval: 3.809, Highest interval: 4.033

# %% [markdown]
# ### Using Z test to validate "notas_filmes_1.rating with 'movielens_average_10_or_more_votes.mean()'

# %%
from statsmodels.stats.weightstats import ztest
movielens_average_10_or_more_votes.mean()
# Out:
# 3.4320503405352603

# %%
zconfint(notas_filme_1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
tstat, p_value = ztest(notas_filme_1.rating, value = movielens_average_10_or_more_votes.mean())
print(p_value)
# Out:
# 8.978190401886942e-18

# %%
print ('H0 rejected') if p_value < 0.05 else print ('H0 accepted')
# Out:
# H0 rejected

# %% [markdown]
# ### Analyzing movie1 mean variation during sample len variation

# %%
np.random.seed(75241)
temp = notas_filme_1.sample(frac=1).rating # Random sample of all items in movielens_.......
medias = [temp[0:i].mean() for i in range(1, len(temp))]
figure(figsize=(12, 8), dpi=80)
plt.plot(medias)

# %% [markdown]
# ### Analyzing p_value and mean variation with sample len

# %%
np.random.seed(75241)
temp = notas_filme_1.sample(frac=1).rating # Random sample of all items in movielens_.......

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p_value = ztest(temp[0:i], value = movielens_average_10_or_more_votes.mean())
    return (i, media, p_value)
    
valores = np.array([calcula_teste(i) for i in range(2, len(temp))])
valores
# figure(figsize=(12, 8), dpi=80)
# plt.plot(valores[:1])
# Out:
# array([[2.00000000e+00, 4.50000000e+00, 3.26876211e-02],
#        [3.00000000e+00, 4.00000000e+00, 3.25254351e-01],
#        [4.00000000e+00, 3.87500000e+00, 2.99521970e-01],
#        [5.00000000e+00, 3.90000000e+00, 1.58267818e-01],
#        [6.00000000e+00, 3.91666667e+00, 7.40693646e-02],
#        [7.00000000e+00, 3.92857143e+00, 3.05837219e-02],
#        [8.00000000e+00, 4.06250000e+00, 8.54684682e-03],
#        [9.00000000e+00, 3.94444444e+00, 3.43513698e-02],
#        [1.00000000e+01, 3.60000000e+00, 6.79775744e-01],
#        [1.10000000e+01, 3.59090909e+00, 6.66104056e-01],
#        [1.20000000e+01, 3.50000000e+00, 8.45259443e-01],
#        [1.30000000e+01, 3.50000000e+00, 8.31972270e-01],
#        [1.40000000e+01, 3.53571429e+00, 7.28503654e-01],
#        [1.50000000e+01, 3.60000000e+00, 5.56156495e-01],
#        [1.60000000e+01, 3.56250000e+00, 6.28416636e-01],
#        [1.70000000e+01, 3.64705882e+00, 4.20561961e-01],
# ...

# %% [markdown]
# ### plotting mean & p_value

# %%
figure(figsize=(12, 8), dpi=80)
plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2])
plt.hlines(y = 0.05, xmin = 2, xmax = len(temp), colors = 'red')

# %%
# p_value
figure(figsize=(12, 8), dpi=80)
plt.plot(valores[:,0], valores[:,2])
plt.hlines(y = 0.05, xmin = 2, xmax = len(temp), colors = 'red')

# %%
# Interval of the diference between the mean of the "notas_filme1" and the general mean
low, high = zconfint(notas_filme_1.rating, notas.rating)
print(f'Movie_1 rating average is between {low.round(4)} and {high.round(4)} higher than the general average')
# Out:
# Movie_1 rating average is between 0.2799 and 0.5588 higher than the general average

# %%
# printing the p_value of the comparisson
_, p_value = ztest(notas_filme_1.rating, notas.rating)
p_value # much lower than the usual 0.05
# Out:
# 3.762112778881965e-09

# %%
# using scipy ttest to try and compare
from scipy.stats import ttest_ind
_, p_value = ttest_ind(notas_filme_1.rating, notas.rating)
p_value
# Out:
# 3.774003138720876e-09

# %%
# using statsmodel "summary" from comparemeans
descr_todas_notas = DescrStatsW(notas.rating)
descr_notas_1 = DescrStatsW(notas_filme_1.rating)
comparacao = descr_todas_notas.get_compare(descr_notas_1) 
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# using boxplot to visually compare 
figure(figsize=(12, 8), dpi=80)
plt.boxplot([notas.rating, notas_filme_1.rating], labels = ['Todas as Notas', 'Toy Story'])
plt.title('Distribuição das notas de acordo com filmes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# lowering the number os samples from film 1 (toy story)
figure(figsize=(12, 8), dpi=80)
plt.boxplot([notas.rating, notas_filme_1.rating[3:12]], labels = ['Todas as Notas', 'Toy Story (notas de 3 a 12)'])
plt.title('Distribuição das notas de acordo com filmes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# using t_test in the lower sample analysis
descr_todas_notas = DescrStatsW(notas.rating)
descr_notas_1 = DescrStatsW(notas_filme_1[3:12].rating)
comparacao = descr_todas_notas.get_compare(descr_notas_1) 
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Comparing mean of two diferent movies

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas1 = notas.query('movieId == 1')
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')

# %%
notas593
# Out:
#        userId  movieId  rating   timestamp
# 34          1      593     4.0   964983793
# 339         4      593     5.0   964539986
# 809         6      593     4.0   845553174
# 888         7      593     5.0  1106635912
# 1071        8      593     4.0   839463470
# ...       ...      ...     ...         ...
# 97132     604      593     5.0   832080562
# 97464     606      593     4.5  1171231373
# 98516     607      593     5.0   964743922
# 98789     608      593     4.0  1117162597
# 99575     610      593     4.5  1479545819
#
# [279 rows x 4 columns]

# %%
figure(figsize=(12, 8), dpi=80)
plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels = ['Toy Story', 'Silence of the Lambs', 'Fantastic Mr.Fox'],  patch_artist=True,
            boxprops={'color':'w'})
plt.title('Distribuição das notas de acordo com filmes')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#using seaborn
ax = sns.boxplot(x = 'movieId', y = 'rating', data = notas.query('movieId == (1, 593, 72226)'))
ax.figure.set_size_inches(12,10)

# %%
# using DescrStatsW to compare means of movie1 and movie593
descr_notas_1 = DescrStatsW(notas1.rating)
descr_notas_593 = DescrStatsW(notas593.rating)
comparacao = descr_notas_1.get_compare(descr_notas_593) 
comparacao.summary(use_t=False)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# using DescrStatsW to compare means of movie593 and movie72226
descr_notas_72226 = DescrStatsW(notas72226.rating)
descr_notas_593 = DescrStatsW(notas593.rating)
comparacao = descr_notas_72226.get_compare(descr_notas_593) 
comparacao.summary(use_t=False)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### analyzing the number of votes

# %%
 notas.query('movieId == (1, 593, 72226)').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
# lowe number of vote_count for id593, must use t_test
# using DescrStatsW to compare means of movie1 and movie593
descr_notas_1 = DescrStatsW(notas1.rating)
descr_notas_593 = DescrStatsW(notas593.rating)
comparacao = descr_notas_1.get_compare(descr_notas_593) 
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
# using DescrStatsW to compare means of movie593 and movie72226
descr_notas_72226 = DescrStatsW(notas72226.rating)
descr_notas_593 = DescrStatsW(notas593.rating)
comparacao = descr_notas_72226.get_compare(descr_notas_593) 
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Testing a series of data for a normal distribuition

# %%
# using scipy
from scipy.stats import normaltest
stat, p = normaltest(notas1.rating)
print(f'Stat: {stat.round(4)}, p_value: {p.round(4)}')
# Out:
# Stat: 18.2204, p_value: 0.0001

# %%
if p < 0.05:
    print('H0 Rejected, series does not come from a normal dist.')
# Out:
# H0 Rejected, series does not come from a normal dist.

# %% [markdown]
# ### Using a non-parametric test (ranksums / wilcoxon)

# %%
from scipy.stats import ranksums
_, p_value = ranksums(notas1.rating, notas593.rating)
p_value.round(5)
print('H0 Rejected, values in one sample are more likely to be larger than the values in the other sample') if p_value < 0.05 else ""
# Out:
# H0 Rejected, values in one sample are more likely to be larger than the values in the other sample
